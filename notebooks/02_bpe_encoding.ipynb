# %%
# %pip install tiktoken
import tiktoken
# Out:
# Requirement already satisfied: tiktoken in /home/gaetan/Documents/barebone-llm-from-scratch/.venv/lib/python3.12/site-packages (0.12.0)
# Requirement already satisfied: regex>=2022.1.18 in /home/gaetan/Documents/barebone-llm-from-scratch/.venv/lib/python3.12/site-packages (from tiktoken) (2026.2.19)
# Requirement already satisfied: requests>=2.26.0 in /home/gaetan/Documents/barebone-llm-from-scratch/.venv/lib/python3.12/site-packages (from tiktoken) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/gaetan/Documents/barebone-llm-from-scratch/.venv/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/gaetan/Documents/barebone-llm-from-scratch/.venv/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/gaetan/Documents/barebone-llm-from-scratch/.venv/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/gaetan/Documents/barebone-llm-from-scratch/.venv/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken) (2026.1.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
tokenizer = tiktoken.get_encoding("gpt2")

# %%
text = ("Hello, do you like tea? <|endoftext|> In the sunlit terraces" "of someunknownPlace." ) 
integers = tokenizer.encode(text, allowed_special = {"<|endoftext|>"})
print(integers)
# Out:
# [15496, 11, 466, 345, 588, 8887, 30, 220, 50256, 554, 262, 4252, 18250, 8812, 2114, 1659, 617, 34680, 27271, 13]

# %%
strings = tokenizer.decode(integers)
print(strings)
# Out:
# Hello, do you like tea? <|endoftext|> In the sunlit terracesof someunknownPlace.

# %%
from pathlib import Path
project_root = Path.cwd().parent
filepath = project_root / "data" / "the-verdict.txt"

with open(filepath, "r", encoding="utf-8") as f: 
    raw_text = f.read()

# %%
enc_text = tokenizer.encode(raw_text) 
print(len(enc_text))
enc_sample = enc_text[50:]
# Out:
# 5145
